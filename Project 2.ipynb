# %% [markdown]
# # Unemployment Analysis using Python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Unemployment in India.csv")

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 763             NaN          NaN       NaN                              NaN
# 764             NaN          NaN       NaN                              NaN
# 765             NaN          NaN       NaN                              NaN
# 766             NaN          NaN       NaN                              NaN
# 767             NaN          NaN       NaN                              NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
df.shape
# Out:
# (768, 7)

# %%
df.isnull().sum()
# Out:
# Region                                     28
# Date                                       28
# Frequency                                  28
# Estimated Unemployment Rate (%)            28
# Estimated Employed                         28
# Estimated Labour Participation Rate (%)    28
# Area                                       28
# dtype: int64

# %%
df['Region'].value_counts(dropna=False)
# Out:
# Andhra Pradesh      28
# Kerala              28
# NaN                 28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
df['Date'].value_counts(dropna=False)
# Out:
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# NaN            28
# Name: Date, dtype: int64

# %%
df['Estimated Employed'].value_counts(dropna=False)
# Out:
# NaN          28
# 247210.0      1
# 233029.0      1
# 241366.0      1
# 246596.0      1
#              ..
# 6021921.0     1
# 6395022.0     1
# 6164215.0     1
# 6189471.0     1
# 9088931.0     1
# Name: Estimated Employed, Length: 741, dtype: int64

# %%
df['Estimated Unemployment Rate (%)'].value_counts(dropna=False)
# Out:
# NaN      28
# 0.00     11
# 3.31      4
# 5.35      3
# 3.66      3
#          ..
# 13.70     1
# 4.03      1
# 40.59     1
# 3.69      1
# 9.86      1
# Name: Estimated Unemployment Rate (%), Length: 625, dtype: int64

# %%
df['Estimated Labour Participation Rate (%)'].value_counts(dropna=False)
# Out:
# NaN      28
# 40.43     3
# 42.82     3
# 39.92     3
# 43.25     3
#          ..
# 44.08     1
# 46.50     1
# 45.79     1
# 44.79     1
# 40.67     1
# Name: Estimated Labour Participation Rate (%), Length: 627, dtype: int64

# %%
df['Area'].value_counts(dropna=False)
# Out:
# Urban    381
# Rural    359
# NaN       28
# Name: Area, dtype: int64

# %% [markdown]
# # Dropping Null Values as there are more Nan Values

# %%
df=df.dropna()
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %% [markdown]
# # Data Visualisation

# %%
sns.pairplot(df,hue = "Region", height=4)

# %%
sns.distplot(df["Estimated Unemployment Rate (%)"])
plt.show()

# %%
sns.scatterplot(x="Region",y="Estimated Unemployment Rate (%)",data=df)
plt.show()

# %%
sns.stripplot(x="Region",y="Estimated Unemployment Rate (%)",data=df)
plt.show()

# %% [markdown]
# There are Many Outliers Present

# %%
sns.boxplot(x=df["Estimated Unemployment Rate (%)"])
plt.show()

# %%
sns.swarmplot(x="Region",y="Estimated Unemployment Rate (%)",data=df)

plt.title('Unemployment Rates by Region')
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate (%)')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.countplot(x='Estimated Unemployment Rate (%)',data=df)

plt.title('Unemployment Rates by Region')

plt.show()

# %%
sns.violinplot(x="Region",y="Estimated Unemployment Rate (%)",data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Estimated Unemployment Rate (%)'>

# %% [markdown]
# # Employement and unemployment rate are two opposite things. It Follows negative Correlation that if one increases, then the other decreases.
# # So, we can drop one of them, but let's check first via a simple line plot and correlation matrix.

# %%
Employed = df['Estimated Employed'].iloc[:50]
Unemployed = df['Estimated Unemployment Rate (%)'].iloc[:50]

#normalize the employed in range 1 to 20
Employed = (Employed - Employed.min())/(Employed.max() - Employed.min()) * 19 + 1

plt.figure(figsize=(12,10))
plt.plot(Employed, label='Employed', color='blue')
plt.plot(Unemployed, label='Unemployed', color='red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(df['Estimated Employed'].corr(df['Estimated Unemployment Rate (%)']))
# Out:
# -0.2228763995221479

# %%
df = df.drop(['Estimated Employed'], axis=1)
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
#      Estimated Labour Participation Rate (%)   Area
# ...

# %%
df[['Day','Month','Year']] = df.Date.str.split("-",expand=True,)
df = df.drop(['Date'], axis=1)
df
# Out:
#              Region Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   Monthly                             3.65
# 1    Andhra Pradesh   Monthly                             3.05
# 2    Andhra Pradesh   Monthly                             3.75
# 3    Andhra Pradesh   Monthly                             3.32
# 4    Andhra Pradesh   Monthly                             5.17
# ..              ...       ...                              ...
# 749     West Bengal   Monthly                             7.55
# 750     West Bengal   Monthly                             6.67
# 751     West Bengal   Monthly                            15.63
# 752     West Bengal   Monthly                            15.22
# 753     West Bengal   Monthly                             9.86
#
#      Estimated Labour Participation Rate (%)   Area  Day Month  Year
# 0                                      43.24  Rural   31    05  2019
# 1                                      42.05  Rural   30    06  2019
# ...

# %%
group = df.groupby(['Region','Area']).agg({'Estimated Unemployment Rate (%)': 'mean'})
group
# Out:
#                         Estimated Unemployment Rate (%)
# Region           Area
# Andhra Pradesh   Rural                         5.526429
#                  Urban                         9.427857
# Assam            Rural                         4.490833
#                  Urban                         8.088571
# Bihar            Rural                        16.770000
#                  Urban                        21.066429
# Chandigarh       Urban                        15.991667
# Chhattisgarh     Rural                         6.628571
#                  Urban                        11.852143
# Delhi            Rural                        15.258571
#                  Urban                        17.732143
# Goa              Rural                         8.390000
#                  Urban                        10.158333
# Gujarat          Rural                         5.917143
#                  Urban                         7.410714
# ...

# %%
df
# Out:
#              Region Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   Monthly                             3.65
# 1    Andhra Pradesh   Monthly                             3.05
# 2    Andhra Pradesh   Monthly                             3.75
# 3    Andhra Pradesh   Monthly                             3.32
# 4    Andhra Pradesh   Monthly                             5.17
# ..              ...       ...                              ...
# 749     West Bengal   Monthly                             7.55
# 750     West Bengal   Monthly                             6.67
# 751     West Bengal   Monthly                            15.63
# 752     West Bengal   Monthly                            15.22
# 753     West Bengal   Monthly                             9.86
#
#      Estimated Labour Participation Rate (%)   Area  Day Month  Year
# 0                                      43.24  Rural   31    05  2019
# 1                                      42.05  Rural   30    06  2019
# ...

# %%
group = df.groupby(['Region','Area']).agg({'Estimated Labour Participation Rate (%)': 'mean'})
group
# Out:
#                         Estimated Labour Participation Rate (%)
# Region           Area
# Andhra Pradesh   Rural                                42.963571
#                  Urban                                35.787857
# Assam            Rural                                47.072500
#                  Urban                                42.979286
# Bihar            Rural                                38.417143
#                  Urban                                37.890714
# Chandigarh       Urban                                39.336667
# Chhattisgarh     Rural                                42.442857
#                  Urban                                43.178571
# Delhi            Rural                                36.993571
#                  Urban                                40.865714
# Goa              Rural                                38.853333
#                  Urban                                39.645833
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Unemployment Rate is Higher in Urban Areas of The Country than in Rural Areas
#
# Unemployment Rate is Highest in the State of Tripura(Urban)-  29.5342%
#
# Unemployment Rate is Least in the State of Meghalaya(Rural)-   2.4750%
#
# Estimated Labour Participation Rate is Highest in the State of Meghalaya(Rural)-   63.4514%
#
# Estimated Labour Participation Rate is Least in the State of Uttharakhand(Urban) -  31.690%
